# %% [markdown]
# # SQL Python connect

# %%
from sqlalchemy import create_engine, text
import pymysql
import pandas as pd
import os

# %%
engine1 = create_engine("mysql+pymysql://root:piit2025@localhost:3306/piit")
engine1
# Out:
# Engine(mysql+pymysql://root:***@localhost:3306/piit)

# %%
# function to run the query with parameters or query
def q(sql, **params):
    with engine1.connect() as conn:
        return pd.read_sql(text(sql), conn, params=params)

# %%
q('show tables')
# Out:
#   Tables_in_piit
# 0       students

# %%
q('show tables')
# Out:
#   Tables_in_piit
# 0           dept
# 1       students

# %%
q('select * from dept')
# Out:
#    deptno       dname       loc
# 0      10  ACCOUNTING  NEW YORK
# 1      20    RESEARCH    DALLAS
# 2      30       SALES   CHICAGO
# 3      40  OPERATIONS    BOSTON

# %%
q ('select * from emp')
# Out:
#     empno   ename        job     mgr    hiredate     sal    comm  deptno
# 0    1234  DHIRAJ    ANALYST  7839.0  1988-12-17  5000.0   100.0      10
# 1    1235  KHULAN    ANALYST  7839.0  1990-12-17  6000.0   100.0      20
# 2    7369   SMITH      CLERK  7902.0  1980-12-17   800.0     NaN      20
# 3    7499   ALLEN   SALESMAN  7698.0  1981-02-20  1600.0   300.0      30
# 4    7521    WARD   SALESMAN  7698.0  1981-02-22  1250.0   500.0      30
# 5    7566   JONES    MANAGER  7839.0  1981-04-02  2975.0     NaN      20
# 6    7654  MARTIN   SALESMAN  7698.0  1981-09-28  1250.0  1400.0      30
# 7    7698   BLAKE    MANAGER  7839.0  1981-05-01  2850.0     NaN      30
# 8    7782   CLARK    MANAGER  7839.0  1981-06-09  2450.0     NaN      10
# 9    7788   SCOTT    ANALYST  7566.0  1987-04-19  3000.0     NaN      20
# 10   7839    KING  PRESIDENT     NaN  1981-11-17  5000.0     NaN      10
# 11   7844  TURNER   SALESMAN  7698.0  1981-09-08  1500.0     0.0      30
# ...

# %%
emp = q('select * from emp')
emp.head()
# Out:
#    empno   ename       job     mgr    hiredate     sal   comm  deptno
# 0   1234  DHIRAJ   ANALYST  7839.0  1988-12-17  5000.0  100.0      10
# 1   1235  KHULAN   ANALYST  7839.0  1990-12-17  6000.0  100.0      20
# 2   7369   SMITH     CLERK  7902.0  1980-12-17   800.0    NaN      20
# 3   7499   ALLEN  SALESMAN  7698.0  1981-02-20  1600.0  300.0      30
# 4   7521    WARD  SALESMAN  7698.0  1981-02-22  1250.0  500.0      30

# %%
dept = q('select * from dept')
dept.head()
# Out:
#    deptno       dname       loc
# 0      10  ACCOUNTING  NEW YORK
# 1      20    RESEARCH    DALLAS
# 2      30       SALES   CHICAGO
# 3      40  OPERATIONS    BOSTON

# %%
empdept= pd.merge(emp, dept, on='deptno', how='inner')
empdept.head()
# Out:
#    empno   ename       job     mgr    hiredate     sal   comm  deptno  \
# 0   1234  DHIRAJ   ANALYST  7839.0  1988-12-17  5000.0  100.0      10
# 1   1235  KHULAN   ANALYST  7839.0  1990-12-17  6000.0  100.0      20
# 2   7369   SMITH     CLERK  7902.0  1980-12-17   800.0    NaN      20
# 3   7499   ALLEN  SALESMAN  7698.0  1981-02-20  1600.0  300.0      30
# 4   7521    WARD  SALESMAN  7698.0  1981-02-22  1250.0  500.0      30
#
#         dname       loc
# 0  ACCOUNTING  NEW YORK
# 1    RESEARCH    DALLAS
# 2    RESEARCH    DALLAS
# 3       SALES   CHICAGO
# 4       SALES   CHICAGO

# %% [markdown]
# empdept.groupby(dname)
# empdept.head()

# %%
empdept.groupby('dname').size()
# Out:
# dname
# ACCOUNTING    4
# RESEARCH      6
# SALES         6
# dtype: int64

# %%
empdept.head()
# Out:
#    empno   ename       job     mgr    hiredate     sal   comm  deptno  \
# 0   1234  DHIRAJ   ANALYST  7839.0  1988-12-17  5000.0  100.0      10
# 1   1235  KHULAN   ANALYST  7839.0  1990-12-17  6000.0  100.0      20
# 2   7369   SMITH     CLERK  7902.0  1980-12-17   800.0    NaN      20
# 3   7499   ALLEN  SALESMAN  7698.0  1981-02-20  1600.0  300.0      30
# 4   7521    WARD  SALESMAN  7698.0  1981-02-22  1250.0  500.0      30
#
#         dname       loc
# 0  ACCOUNTING  NEW YORK
# 1    RESEARCH    DALLAS
# 2    RESEARCH    DALLAS
# 3       SALES   CHICAGO
# 4       SALES   CHICAGO

# %%
empdept.shape
# Out:
# (16, 10)

# %% [markdown]
# empdept.dtypes

# %% [markdown]
# empdept.dtypes

# %%
empdept.info
# Out:
# <bound method DataFrame.info of     empno   ename        job     mgr    hiredate     sal    comm  deptno  \
# 0    1234  DHIRAJ    ANALYST  7839.0  1988-12-17  5000.0   100.0      10
# 1    1235  KHULAN    ANALYST  7839.0  1990-12-17  6000.0   100.0      20
# 2    7369   SMITH      CLERK  7902.0  1980-12-17   800.0     NaN      20
# 3    7499   ALLEN   SALESMAN  7698.0  1981-02-20  1600.0   300.0      30
# 4    7521    WARD   SALESMAN  7698.0  1981-02-22  1250.0   500.0      30
# 5    7566   JONES    MANAGER  7839.0  1981-04-02  2975.0     NaN      20
# 6    7654  MARTIN   SALESMAN  7698.0  1981-09-28  1250.0  1400.0      30
# 7    7698   BLAKE    MANAGER  7839.0  1981-05-01  2850.0     NaN      30
# 8    7782   CLARK    MANAGER  7839.0  1981-06-09  2450.0     NaN      10
# 9    7788   SCOTT    ANALYST  7566.0  1987-04-19  3000.0     NaN      20
# 10   7839    KING  PRESIDENT     NaN  1981-11-17  5000.0     NaN      10
# ...

# %%
empdept.describe
# Out:
# <bound method NDFrame.describe of     empno   ename        job     mgr    hiredate     sal    comm  deptno  \
# 0    1234  DHIRAJ    ANALYST  7839.0  1988-12-17  5000.0   100.0      10
# 1    1235  KHULAN    ANALYST  7839.0  1990-12-17  6000.0   100.0      20
# 2    7369   SMITH      CLERK  7902.0  1980-12-17   800.0     NaN      20
# 3    7499   ALLEN   SALESMAN  7698.0  1981-02-20  1600.0   300.0      30
# 4    7521    WARD   SALESMAN  7698.0  1981-02-22  1250.0   500.0      30
# 5    7566   JONES    MANAGER  7839.0  1981-04-02  2975.0     NaN      20
# 6    7654  MARTIN   SALESMAN  7698.0  1981-09-28  1250.0  1400.0      30
# 7    7698   BLAKE    MANAGER  7839.0  1981-05-01  2850.0     NaN      30
# 8    7782   CLARK    MANAGER  7839.0  1981-06-09  2450.0     NaN      10
# 9    7788   SCOTT    ANALYST  7566.0  1987-04-19  3000.0     NaN      20
# 10   7839    KING  PRESIDENT     NaN  1981-11-17  5000.0     NaN      10
# ...

# %%
empdept.dtypes
# Out:
# empno         int64
# ename        object
# job          object
# mgr         float64
# hiredate     object
# sal         float64
# comm        float64
# deptno        int64
# dname        object
# loc          object
# dtype: object

# %%
empdept.isnull().sum()
# Out:
# empno        0
# ename        0
# job          0
# mgr          1
# hiredate     0
# sal          0
# comm        10
# deptno       0
# dname        0
# loc          0
# dtype: int64

# %%
empdept['comm'].fillna(0, inplace=True)
# Out:
# /var/folders/w6/x5twkjq11wnbvlzkldcqbgwc0000gn/T/ipykernel_82013/2194825838.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   empdept['comm'].fillna(0, inplace=True)

# %%
# Salary analysis
empdept['sal'].mean()
# Out:
# np.float64(2501.5625)

# %%
empdept['sal'].min()
# Out:
# 800.0

# %%
empdept['sal'].sum()
# Out:
# np.float64(40025.0)

# %%
empdept['sal'].max()
# Out:
# 6000.0

# %%
empdept['sal'].median()
# Out:
# 2025.0

# %%
empdept['sal'].std()
# Out:
# 1617.159772306579

# %%
empdept.groupby('job')['sal'].mean()
# Out:
# job
# ANALYST      4250.000000
# CLERK        1037.500000
# MANAGER      2758.333333
# PRESIDENT    5000.000000
# SALESMAN     1400.000000
# Name: sal, dtype: float64

# %%
empdept.head()
# Out:
#    empno   ename       job     mgr    hiredate     sal   comm  deptno  \
# 0   1234  DHIRAJ   ANALYST  7839.0  1988-12-17  5000.0  100.0      10
# 1   1235  KHULAN   ANALYST  7839.0  1990-12-17  6000.0  100.0      20
# 2   7369   SMITH     CLERK  7902.0  1980-12-17   800.0    0.0      20
# 3   7499   ALLEN  SALESMAN  7698.0  1981-02-20  1600.0  300.0      30
# 4   7521    WARD  SALESMAN  7698.0  1981-02-22  1250.0  500.0      30
#
#         dname       loc
# 0  ACCOUNTING  NEW YORK
# 1    RESEARCH    DALLAS
# 2    RESEARCH    DALLAS
# 3       SALES   CHICAGO
# 4       SALES   CHICAGO

# %%
empdept.groupby('dname')['sal'].mean()
# Out:
# dname
# ACCOUNTING    3437.500000
# RESEARCH      2812.500000
# SALES         1566.666667
# Name: sal, dtype: float64

# %%
#filtering location
empdept.groupby('loc').size()
# Out:
# loc
# CHICAGO     6
# DALLAS      6
# NEW YORK    4
# dtype: int64

# %%
empdept.groupby('dname')['sal'].agg(['mean','max','count'])
# Out:
#                    mean     max  count
# dname
# ACCOUNTING  3437.500000  5000.0      4
# RESEARCH    2812.500000  6000.0      6
# SALES       1566.666667  2850.0      6

# %%
empdept['hiredate'] = pd.to_datetime(empdept['hiredate'])
filtered = empdept[empdept['hiredate'] > '1981-01-01']

# %%
filtered.groupby(filtered['hiredate'].dt.year).size()
filtered.groupby(filtered['hiredate'].dt.year)['sal'].mean()
# Out:
# hiredate
# 1981    2282.5
# 1982    1300.0
# 1987    2050.0
# 1988    5000.0
# 1990    6000.0
# Name: sal, dtype: float64

# %%
empdept.groupby('ename')['sal'].agg(['mean','max','count'])
# Out:
#           mean     max  count
# ename
# ADAMS   1100.0  1100.0      1
# ALLEN   1600.0  1600.0      1
# BLAKE   2850.0  2850.0      1
# CLARK   2450.0  2450.0      1
# DHIRAJ  5000.0  5000.0      1
# FORD    3000.0  3000.0      1
# JAMES    950.0   950.0      1
# JONES   2975.0  2975.0      1
# KHULAN  6000.0  6000.0      1
# KING    5000.0  5000.0      1
# MARTIN  1250.0  1250.0      1
# MILLER  1300.0  1300.0      1
# SCOTT   3000.0  3000.0      1
# SMITH    800.0   800.0      1
# TURNER  1500.0  1500.0      1
# WARD    1250.0  1250.0      1

# %%
empdept.groupby('dname').size()
# Out:
# dname
# ACCOUNTING    4
# RESEARCH      6
# SALES         6
# dtype: int64

# %%
empdept.groupby('dname').count()
# Out:
#             empno  ename  job  mgr  hiredate  sal  comm  deptno  loc
# dname
# ACCOUNTING      4      4    4    3         4    4     4       4    4
# RESEARCH        6      6    6    6         6    6     6       6    6
# SALES           6      6    6    6         6    6     6       6    6

# %%
# Total compensation sal+comm
empdept['total_comp'] = empdept['sal'] + empdept['comm']
empdept[['ename','sal','comm','total_comp']].sort_values('total_comp', ascending=False)
# Out:
#      ename     sal    comm  total_comp
# 1   KHULAN  6000.0   100.0      6100.0
# 0   DHIRAJ  5000.0   100.0      5100.0
# 10    KING  5000.0     0.0      5000.0
# 9    SCOTT  3000.0     0.0      3000.0
# 14    FORD  3000.0     0.0      3000.0
# 5    JONES  2975.0     0.0      2975.0
# 7    BLAKE  2850.0     0.0      2850.0
# 6   MARTIN  1250.0  1400.0      2650.0
# 8    CLARK  2450.0     0.0      2450.0
# 3    ALLEN  1600.0   300.0      1900.0
# 4     WARD  1250.0   500.0      1750.0
# 11  TURNER  1500.0     0.0      1500.0
# 15  MILLER  1300.0     0.0      1300.0
# 12   ADAMS  1100.0     0.0      1100.0
# 13   JAMES   950.0     0.0       950.0
# 2    SMITH   800.0     0.0       800.0

# %%
# Sequencing order number
result = empdept[['ename','sal','comm','total_comp']]\
         .sort_values('total_comp', ascending=False)\
         .reset_index(drop=True)

result.index += 1  # start from 1 instead of 0
result
# Out:
#      ename     sal    comm  total_comp
# 1   KHULAN  6000.0   100.0      6100.0
# 2   DHIRAJ  5000.0   100.0      5100.0
# 3     KING  5000.0     0.0      5000.0
# 4    SCOTT  3000.0     0.0      3000.0
# 5     FORD  3000.0     0.0      3000.0
# 6    JONES  2975.0     0.0      2975.0
# 7    BLAKE  2850.0     0.0      2850.0
# 8   MARTIN  1250.0  1400.0      2650.0
# 9    CLARK  2450.0     0.0      2450.0
# 10   ALLEN  1600.0   300.0      1900.0
# 11    WARD  1250.0   500.0      1750.0
# 12  TURNER  1500.0     0.0      1500.0
# 13  MILLER  1300.0     0.0      1300.0
# 14   ADAMS  1100.0     0.0      1100.0
# 15   JAMES   950.0     0.0       950.0
# 16   SMITH   800.0     0.0       800.0

# %%
empdept[empdept['hiredate'] > '1981-01-01']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 empdept[empdept['hiredate'] > '1981-01-01']
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/arraylike.py:56, in OpsMixin.__gt__(self, other)
#      54 @unpack_zerodim_and_defer("__gt__")
#      55 def __gt__(self, other):
# ---> 56     return self._cmp_method(other, operator.gt)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/series.py:6138, in Series._cmp_method(self, other, op)
#    6135 lvalues = self._values
#    6136 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# ...

# %%
empdept[empdept['hiredate'] > '1981-01-01'].sort_values('hiredate')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 empdept[empdept['hiredate'] > '1981-01-01'].sort_values('hiredate')
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/arraylike.py:56, in OpsMixin.__gt__(self, other)
#      54 @unpack_zerodim_and_defer("__gt__")
#      55 def __gt__(self, other):
# ---> 56     return self._cmp_method(other, operator.gt)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/series.py:6138, in Series._cmp_method(self, other, op)
#    6135 lvalues = self._values
# ...
