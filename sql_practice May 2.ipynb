# %% [markdown]
# # SQL - Python connect

# %%
#pip install sqlalchemy
#pip install pymysql

# %%
# !pip install pymysql

# %%
from sqlalchemy import create_engine, text
import pandas as pd
import os

# %%
# URL-encode special chars in password if any (e.g., # -> %23, @ -> %40)  #Pass@123 - Pass%40123
engine1 = create_engine("mysql+pymysql://root:piit2025@localhost:3306/piit")
# URL-encode special chars in password if any (e.g., # -> %23, @ -> %40)  #Pass@123 - Pass%40123
#engine1 = create_engine("mysql+pymysql://root:piit2026@localhost:3306/piit")
print(engine1)
#setting up connection mysql with user name - piuser, pwd - Pass@123 and to database piit at port no  3306
# Out:
# Engine(mysql+pymysql://root:***@localhost:3306/piit)

# %%
def q(sql, **params):
    with engine1.connect() as conn:
        return pd.read_sql(text(sql), conn, params=params)

# %%
q("SELECT * FROM students")
# Out:
#     id                 name            branch  score   exam_date  \
# 0    1         Rick Johnson        Mechanical  63.68  2025-03-30
# 1    2         Shannon Hall        Electrical  74.35  2024-03-28
# 2    3     Stephanie Flores  Computer Science  88.97  2024-05-17
# 3    4        Keith Ferrell             Civil  75.00  2025-06-22
# 4    5          Corey Allen  Computer Science  63.14  2025-05-17
# 5    6    Brittney Galloway  Computer Science  51.85  2025-02-01
# 6    7       Kathryn Gordon        Electrical  70.88  2023-12-10
# 7    8         Julia Warren        Electrical  63.07  2023-11-21
# 8    9     Carol Cunningham  Computer Science  87.88  2024-07-29
# 9   10     Cassidy Crawford             Civil  52.46  2025-02-25
# 10  11      William Sanders       Electronics  53.81  2024-01-02
# 11  12       Amanda Chapman        Mechanical  58.49  2025-03-04
# 12  13         Amanda Reese       Electronics  54.26  2023-10-15
# ...

# %% [raw]
# select * from students;
# select * from students where branch = "Civil";
# select * from students where branch = "Mechanical";
# select * from studets where name like 'R%';
# select sum(score) from students;
# select max(score) from students;
# select min(score) from students;
# select avg(score) from students;
# select branch, avg(score) as avgscore from students group by branch;
# select branch, avg(score) as avgscore, count(*) from students group by branch;
# select * from students order by score desc;

# %%
q("select * from students where branch = 'Civil';")
# Out:
#    id              name branch  score   exam_date      remarks
# 0   4     Keith Ferrell  Civil  75.00  2025-06-22      Average
# 1  10  Cassidy Crawford  Civil  52.46  2025-02-25    Excellent
# 2  14  Katherine Morrow  Civil  85.95  2023-09-23  Outstanding
# 3  20   Rhonda Sullivan  Civil  88.30  2024-02-04  Outstanding
# 4  22       Emily Moore  Civil  65.21  2024-03-15  Outstanding
# 5  23   Robert Delacruz  Civil  51.92  2024-02-15         Good
# 6  27    Anna Zimmerman  Civil  83.72  2024-10-28      Average

# %%
q("select * from students where branch = 'Mechanical';")
# Out:
#    id            name      branch  score   exam_date      remarks
# 0   1    Rick Johnson  Mechanical  63.68  2025-03-30      Average
# 1  12  Amanda Chapman  Mechanical  58.49  2025-03-04  Outstanding
# 2  25     Danielle Le  Mechanical  91.50  2024-02-28  Outstanding

# %%
import pandas as pd

# %%
df2 = pd.read_sql("SELECT * FROM students" , engine1)
df2.shape
df2
# Out:
#     id                 name            branch  score   exam_date  \
# 0    1         Rick Johnson        Mechanical  63.68  2025-03-30
# 1    2         Shannon Hall        Electrical  74.35  2024-03-28
# 2    3     Stephanie Flores  Computer Science  88.97  2024-05-17
# 3    4        Keith Ferrell             Civil  75.00  2025-06-22
# 4    5          Corey Allen  Computer Science  63.14  2025-05-17
# 5    6    Brittney Galloway  Computer Science  51.85  2025-02-01
# 6    7       Kathryn Gordon        Electrical  70.88  2023-12-10
# 7    8         Julia Warren        Electrical  63.07  2023-11-21
# 8    9     Carol Cunningham  Computer Science  87.88  2024-07-29
# 9   10     Cassidy Crawford             Civil  52.46  2025-02-25
# 10  11      William Sanders       Electronics  53.81  2024-01-02
# 11  12       Amanda Chapman        Mechanical  58.49  2025-03-04
# 12  13         Amanda Reese       Electronics  54.26  2023-10-15
# ...

# %%
#Average score
df2.groupby('branch')['score'].mean()
# Out:
# branch
# Civil               71.794286
# Computer Science    78.506250
# Electrical          75.497500
# Electronics         58.110000
# Mechanical          71.223333
# Name: score, dtype: float64

# %%
df2.groupby('remarks')['score'].mean()
# Out:
# remarks
# Average              71.797778
# Excellent            77.410000
# Good                 63.483333
# Needs Improvement    60.345000
# Outstanding          75.580000
# Name: score, dtype: float64

# %%
df2.groupby(['branch','remarks'])['score'].mean()
# Out:
# branch            remarks
# Civil             Average              79.360000
#                   Excellent            52.460000
#                   Good                 51.920000
#                   Outstanding          79.820000
# Computer Science  Average              91.825000
#                   Excellent            86.080000
#                   Good                 87.880000
#                   Needs Improvement    59.996667
#                   Outstanding          90.450000
# Electrical        Excellent            93.690000
#                   Needs Improvement    63.070000
#                   Outstanding          72.615000
# Electronics       Average              60.032500
#                   Good                 50.650000
#                   Needs Improvement    59.505000
#                   Outstanding          55.090000
# Mechanical        Average              63.680000
#                   Outstanding          74.995000
# Name: score, dtype: float64

# %%
df2.groupby(['branch','remarks'])['score'].max()
# Out:
# branch            remarks
# Civil             Average              83.72
#                   Excellent            52.46
#                   Good                 51.92
#                   Outstanding          88.30
# Computer Science  Average              94.68
#                   Excellent            86.08
#                   Good                 87.88
#                   Needs Improvement    65.00
#                   Outstanding          90.45
# Electrical        Excellent            93.69
#                   Needs Improvement    63.07
#                   Outstanding          74.35
# Electronics       Average              78.04
#                   Good                 50.65
#                   Needs Improvement    64.88
#                   Outstanding          55.09
# Mechanical        Average              63.68
#                   Outstanding          91.50
# Name: score, dtype: float64

# %%
df2.groupby(['branch','remarks'])['score'].min()
# Out:
# branch            remarks
# Civil             Average              75.00
#                   Excellent            52.46
#                   Good                 51.92
#                   Outstanding          65.21
# Computer Science  Average              88.97
#                   Excellent            86.08
#                   Good                 87.88
#                   Needs Improvement    51.85
#                   Outstanding          90.45
# Electrical        Excellent            93.69
#                   Needs Improvement    63.07
#                   Outstanding          70.88
# Electronics       Average              53.81
#                   Good                 50.65
#                   Needs Improvement    54.13
#                   Outstanding          55.09
# Mechanical        Average              63.68
#                   Outstanding          58.49
# Name: score, dtype: float64

# %%
df2.groupby(['branch','remarks'])['score'].min()
# Out:
# branch            remarks
# Civil             Average              75.00
#                   Excellent            52.46
#                   Good                 51.92
#                   Outstanding          65.21
# Computer Science  Average              88.97
#                   Excellent            86.08
#                   Good                 87.88
#                   Needs Improvement    51.85
#                   Outstanding          90.45
# Electrical        Excellent            93.69
#                   Needs Improvement    63.07
#                   Outstanding          70.88
# Electronics       Average              53.81
#                   Good                 50.65
#                   Needs Improvement    54.13
#                   Outstanding          55.09
# Mechanical        Average              63.68
#                   Outstanding          58.49
# Name: score, dtype: float64

# %%
df2.groupby(['branch','remarks'])['score'].agg(['min','max','mean'])
# Out:
#                                       min    max       mean
# branch           remarks
# Civil            Average            75.00  83.72  79.360000
#                  Excellent          52.46  52.46  52.460000
#                  Good               51.92  51.92  51.920000
#                  Outstanding        65.21  88.30  79.820000
# Computer Science Average            88.97  94.68  91.825000
#                  Excellent          86.08  86.08  86.080000
#                  Good               87.88  87.88  87.880000
#                  Needs Improvement  51.85  65.00  59.996667
#                  Outstanding        90.45  90.45  90.450000
# Electrical       Excellent          93.69  93.69  93.690000
#                  Needs Improvement  63.07  63.07  63.070000
#                  Outstanding        70.88  74.35  72.615000
# Electronics      Average            53.81  78.04  60.032500
#                  Good               50.65  50.65  50.650000
# ...

# %%
import datetime as dt

# %%
empdept['hiredate'] = pd.to_datetime(empdept['hiredate'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 empdept['hiredate'] = pd.to_datetime(empdept['hiredate'])
#
# NameError: name 'empdept' is not defined

# %%
empdept.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 empdept.head()
#
# NameError: name 'empdept' is not defined
