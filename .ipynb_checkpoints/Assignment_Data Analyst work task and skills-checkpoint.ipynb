# %% [markdown]
# # Data Analyst Tasks

# %%
#Tasks & Skills

# %%
# Data Collection- Gather Raw Data From library or Database

# %%
# Data Cleaning: Fix errors, fill missing values

# %%
#Exploratory Analysis: Spot trends and pattersn

# %%
#Statistical Analysis: Apply Quantitative Methods
#Data visualization: charts, dashboards, reports,
#Reporting &Storytelling: Communicating finding Clearly

# %%
# Predictive Modeling: forecastiing future outcomes with the data
#SQL Querying: Extract data from databases
#businessAcumen: Translate data to decisions

# %% [markdown]
# # Core Skills

# %%
#Python, SQL, Excel/Sheets, Tableu/Power BI, Statistics, Critical Thinking, Data storytelling, Attenttion to details and Stakeholder communication

# %%
#Data analysing steps:
1. Define Problem: without clear question, analysis has no direction
2. Collect data: Pull from databases, APIs, spreadsheets, surveys, or third-party sources
3. Clean&Prepare data: Handle null, duplicates, outliers;Reformat; validate data integrity
#Consuming most of the work 
4. Explore & analyse: Find pattern, test and segment the data
5. Visualize&Model: create a charts, dashboards, or predictive models to surface insights to easy  understanding
6. Present & act: Deliver findings to stakeholders, recommend actions, track outcomes
