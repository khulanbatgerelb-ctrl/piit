# %% [markdown]
# # Advanced Panda Functions

# %%
import numpy as np
import pandas as pd

# %%
pd.set_option('display.max_columns',None)

# %%
from pydataset import data
mtcars = data('mtcars')
mtcars.head()
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#                    carb
# Mazda RX4             4
# Mazda RX4 Wag         4
# Datsun 710            1
# Hornet 4 Drive        1
# Hornet Sportabout     2

# %%
mtcars.dtypes
# Out:
# mpg     float64
# cyl       int64
# disp    float64
# hp        int64
# drat    float64
# wt      float64
# qsec    float64
# vs        int64
# am        int64
# gear      int64
# carb      int64
# dtype: object

# %%
mtcars.head(3)
# Out:
#                 mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# Mazda RX4      21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# Datsun 710     22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1

# %%
mtcars = data('mtcars')
mtcars = mtcars.astype({ 'cyl': 'category', 'vs': 'category', 'carb': 'category', 'am': 'category', 'gear': 'category'})

# %%
mtcars.dtypes
# Out:
# mpg      float64
# cyl     category
# disp     float64
# hp         int64
# drat     float64
# wt       float64
# qsec     float64
# vs      category
# am      category
# gear    category
# carb    category
# dtype: object

# %%
mtcars.head()
# Out:
#                     mpg cyl   disp   hp  drat     wt   qsec vs am gear carb
# Mazda RX4          21.0   6  160.0  110  3.90  2.620  16.46  0  1    4    4
# Mazda RX4 Wag      21.0   6  160.0  110  3.90  2.875  17.02  0  1    4    4
# Datsun 710         22.8   4  108.0   93  3.85  2.320  18.61  1  1    4    1
# Hornet 4 Drive     21.4   6  258.0  110  3.08  3.215  19.44  1  0    3    1
# Hornet Sportabout  18.7   8  360.0  175  3.15  3.440  17.02  0  0    3    2

# %%
mtcars['am'] =mtcars['am'].map({0: 'auto', 1:'manual'})
mtcars.head() #sorting by manual or automatic engine
# Out:
#                     mpg cyl   disp   hp  drat     wt   qsec vs      am gear  \
# Mazda RX4          21.0   6  160.0  110  3.90  2.620  16.46  0  manual    4
# Mazda RX4 Wag      21.0   6  160.0  110  3.90  2.875  17.02  0  manual    4
# Datsun 710         22.8   4  108.0   93  3.85  2.320  18.61  1  manual    4
# Hornet 4 Drive     21.4   6  258.0  110  3.08  3.215  19.44  1    auto    3
# Hornet Sportabout  18.7   8  360.0  175  3.15  3.440  17.02  0    auto    3
#
#                   carb
# Mazda RX4            4
# Mazda RX4 Wag        4
# Datsun 710           1
# Hornet 4 Drive       1
# Hornet Sportabout    2

# %%
mtcars['mpg'].max()
# Out:
# 33.9

# %%
bins = [0, 17, 29, mtcars['mpg'].max()]
labels = ['Low', 'Medium', 'High']

# %%
mtcars['mpg_level'] = pd.cut(mtcars['mpg'], bins=bins, labels=labels, include_lowest=True)

# %%
mtcars.head()
# Out:
#                     mpg cyl   disp   hp  drat     wt   qsec vs      am gear  \
# Mazda RX4          21.0   6  160.0  110  3.90  2.620  16.46  0  manual    4
# Mazda RX4 Wag      21.0   6  160.0  110  3.90  2.875  17.02  0  manual    4
# Datsun 710         22.8   4  108.0   93  3.85  2.320  18.61  1  manual    4
# Hornet 4 Drive     21.4   6  258.0  110  3.08  3.215  19.44  1    auto    3
# Hornet Sportabout  18.7   8  360.0  175  3.15  3.440  17.02  0    auto    3
#
#                   carb mpg_level
# Mazda RX4            4    Medium
# Mazda RX4 Wag        4    Medium
# Datsun 710           1    Medium
# Hornet 4 Drive       1    Medium
# Hornet Sportabout    2    Medium

# %%
mtcars.groupby('mpg_level')['mpg'].count()
# Out:
# /var/folders/w6/x5twkjq11wnbvlzkldcqbgwc0000gn/T/ipykernel_62937/4182853279.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mtcars.groupby('mpg_level')['mpg'].count()
# mpg_level
# Low       11
# Medium    17
# High       4
# Name: mpg, dtype: int64

# %%
mtcars.mpg_level.value_counts()
# Out:
# mpg_level
# Medium    17
# Low       11
# High       4
# Name: count, dtype: int64

# %%
mtcars['vs'] = mtcars['vs'].map({0: 'Vshaped', 1:'Straight'})
mtcars.head()
# Out:
#                     mpg cyl   disp   hp  drat     wt   qsec        vs      am  \
# Mazda RX4          21.0   6  160.0  110  3.90  2.620  16.46   Vshaped  manual
# Mazda RX4 Wag      21.0   6  160.0  110  3.90  2.875  17.02   Vshaped  manual
# Datsun 710         22.8   4  108.0   93  3.85  2.320  18.61  Straight  manual
# Hornet 4 Drive     21.4   6  258.0  110  3.08  3.215  19.44  Straight    auto
# Hornet Sportabout  18.7   8  360.0  175  3.15  3.440  17.02   Vshaped    auto
#
#                   gear carb mpg_level
# Mazda RX4            4    4    Medium
# Mazda RX4 Wag        4    4    Medium
# Datsun 710           4    1    Medium
# Hornet 4 Drive       3    1    Medium
# Hornet Sportabout    3    2    Medium

# %%
mtcars.reset_index()
# Out:
#                   index   mpg cyl   disp   hp  drat     wt   qsec        vs  \
# 0             Mazda RX4  21.0   6  160.0  110  3.90  2.620  16.46   Vshaped
# 1         Mazda RX4 Wag  21.0   6  160.0  110  3.90  2.875  17.02   Vshaped
# 2            Datsun 710  22.8   4  108.0   93  3.85  2.320  18.61  Straight
# 3        Hornet 4 Drive  21.4   6  258.0  110  3.08  3.215  19.44  Straight
# 4     Hornet Sportabout  18.7   8  360.0  175  3.15  3.440  17.02   Vshaped
# 5               Valiant  18.1   6  225.0  105  2.76  3.460  20.22  Straight
# 6            Duster 360  14.3   8  360.0  245  3.21  3.570  15.84   Vshaped
# 7             Merc 240D  24.4   4  146.7   62  3.69  3.190  20.00  Straight
# 8              Merc 230  22.8   4  140.8   95  3.92  3.150  22.90  Straight
# 9              Merc 280  19.2   6  167.6  123  3.92  3.440  18.30  Straight
# 10            Merc 280C  17.8   6  167.6  123  3.92  3.440  18.90  Straight
# 11           Merc 450SE  16.4   8  275.8  180  3.07  4.070  17.40   Vshaped
# 12           Merc 450SL  17.3   8  275.8  180  3.07  3.730  17.60   Vshaped
# 13          Merc 450SLC  15.2   8  275.8  180  3.07  3.780  18.00   Vshaped
# 14   Cadillac Fleetwood  10.4   8  472.0  205  2.93  5.250  17.98   Vshaped
# 15  Lincoln Continental  10.4   8  460.0  215  3.00  5.424  17.82   Vshaped
# 16    Chrysler Imperial  14.7   8  440.0  230  3.23  5.345  17.42   Vshaped
# 17             Fiat 128  32.4   4   78.7   66  4.08  2.200  19.47  Straight
# 18          Honda Civic  30.4   4   75.7   52  4.93  1.615  18.52  Straight
# 19       Toyota Corolla  33.9   4   71.1   65  4.22  1.835  19.90  Straight
# 20        Toyota Corona  21.5   4  120.1   97  3.70  2.465  20.01  Straight
# 21     Dodge Challenger  15.5   8  318.0  150  2.76  3.520  16.87   Vshaped
# 22          AMC Javelin  15.2   8  304.0  150  3.15  3.435  17.30   Vshaped
# 23           Camaro Z28  13.3   8  350.0  245  3.73  3.840  15.41   Vshaped
# 24     Pontiac Firebird  19.2   8  400.0  175  3.08  3.845  17.05   Vshaped
# 25            Fiat X1-9  27.3   4   79.0   66  4.08  1.935  18.90  Straight
# 26        Porsche 914-2  26.0   4  120.3   91  4.43  2.140  16.70   Vshaped
# 27         Lotus Europa  30.4   4   95.1  113  3.77  1.513  16.90  Straight
# 28       Ford Pantera L  15.8   8  351.0  264  4.22  3.170  14.50   Vshaped
# 29         Ferrari Dino  19.7   6  145.0  175  3.62  2.770  15.50   Vshaped
# 30        Maserati Bora  15.0   8  301.0  335  3.54  3.570  14.60   Vshaped
# 31           Volvo 142E  21.4   4  121.0  109  4.11  2.780  18.60  Straight
#
#         am gear carb mpg_level
# 0   manual    4    4    Medium
# 1   manual    4    4    Medium
# 2   manual    4    1    Medium
# 3     auto    3    1    Medium
# 4     auto    3    2    Medium
# 5     auto    3    1    Medium
# 6     auto    3    4       Low
# 7     auto    4    2    Medium
# 8     auto    4    2    Medium
# 9     auto    4    4    Medium
# 10    auto    4    4    Medium
# 11    auto    3    3       Low
# 12    auto    3    3    Medium
# 13    auto    3    3       Low
# 14    auto    3    4       Low
# 15    auto    3    4       Low
# 16    auto    3    4       Low
# 17  manual    4    1      High
# 18  manual    4    2      High
# 19  manual    4    1      High
# 20    auto    3    1    Medium
# 21    auto    3    2       Low
# 22    auto    3    2       Low
# 23    auto    3    4       Low
# 24    auto    3    2    Medium
# 25  manual    4    1    Medium
# 26  manual    5    2    Medium
# 27  manual    5    2      High
# 28  manual    5    4       Low
# 29  manual    5    6    Medium
# 30  manual    5    8       Low
# 31  manual    4    2    Medium

# %%
mtcars.index
# Out:
# Index(['Mazda RX4', 'Mazda RX4 Wag', 'Datsun 710', 'Hornet 4 Drive',
#        'Hornet Sportabout', 'Valiant', 'Duster 360', 'Merc 240D', 'Merc 230',
#        'Merc 280', 'Merc 280C', 'Merc 450SE', 'Merc 450SL', 'Merc 450SLC',
#        'Cadillac Fleetwood', 'Lincoln Continental', 'Chrysler Imperial',
#        'Fiat 128', 'Honda Civic', 'Toyota Corolla', 'Toyota Corona',
#        'Dodge Challenger', 'AMC Javelin', 'Camaro Z28', 'Pontiac Firebird',
#        'Fiat X1-9', 'Porsche 914-2', 'Lotus Europa', 'Ford Pantera L',
#        'Ferrari Dino', 'Maserati Bora', 'Volvo 142E'],
#       dtype='object')

# %%
mtcars.head()
# Out:
#                     mpg cyl   disp   hp  drat     wt   qsec        vs      am  \
# Mazda RX4          21.0   6  160.0  110  3.90  2.620  16.46   Vshaped  manual
# Mazda RX4 Wag      21.0   6  160.0  110  3.90  2.875  17.02   Vshaped  manual
# Datsun 710         22.8   4  108.0   93  3.85  2.320  18.61  Straight  manual
# Hornet 4 Drive     21.4   6  258.0  110  3.08  3.215  19.44  Straight    auto
# Hornet Sportabout  18.7   8  360.0  175  3.15  3.440  17.02   Vshaped    auto
#
#                   gear carb mpg_level
# Mazda RX4            4    4    Medium
# Mazda RX4 Wag        4    4    Medium
# Datsun 710           4    1    Medium
# Hornet 4 Drive       3    1    Medium
# Hornet Sportabout    3    2    Medium

# %%
mtcars['car_name'] = mtcars.index
mtcars.head()
# Out:
#                     mpg cyl   disp   hp  drat     wt   qsec        vs      am  \
# Mazda RX4          21.0   6  160.0  110  3.90  2.620  16.46   Vshaped  manual
# Mazda RX4 Wag      21.0   6  160.0  110  3.90  2.875  17.02   Vshaped  manual
# Datsun 710         22.8   4  108.0   93  3.85  2.320  18.61  Straight  manual
# Hornet 4 Drive     21.4   6  258.0  110  3.08  3.215  19.44  Straight    auto
# Hornet Sportabout  18.7   8  360.0  175  3.15  3.440  17.02   Vshaped    auto
#
#                   gear carb mpg_level           car_name
# Mazda RX4            4    4    Medium          Mazda RX4
# Mazda RX4 Wag        4    4    Medium      Mazda RX4 Wag
# Datsun 710           4    1    Medium         Datsun 710
# Hornet 4 Drive       3    1    Medium     Hornet 4 Drive
# Hornet Sportabout    3    2    Medium  Hornet Sportabout

# %%
mtcars['model'] = mtcars.index #carnames & model & carno.

# %%
mtcars.head()
# Out:
#                     mpg cyl   disp   hp  drat     wt   qsec        vs      am  \
# Mazda RX4          21.0   6  160.0  110  3.90  2.620  16.46   Vshaped  manual
# Mazda RX4 Wag      21.0   6  160.0  110  3.90  2.875  17.02   Vshaped  manual
# Datsun 710         22.8   4  108.0   93  3.85  2.320  18.61  Straight  manual
# Hornet 4 Drive     21.4   6  258.0  110  3.08  3.215  19.44  Straight    auto
# Hornet Sportabout  18.7   8  360.0  175  3.15  3.440  17.02   Vshaped    auto
#
#                   gear carb mpg_level           car_name              model
# Mazda RX4            4    4    Medium          Mazda RX4          Mazda RX4
# Mazda RX4 Wag        4    4    Medium      Mazda RX4 Wag      Mazda RX4 Wag
# Datsun 710           4    1    Medium         Datsun 710         Datsun 710
# Hornet 4 Drive       3    1    Medium     Hornet 4 Drive     Hornet 4 Drive
# Hornet Sportabout    3    2    Medium  Hornet Sportabout  Hornet Sportabout

# %%
mtcars.dtypes
# Out:
# mpg           float64
# cyl          category
# disp          float64
# hp              int64
# drat          float64
# wt            float64
# qsec          float64
# vs           category
# am           category
# gear         category
# carb         category
# mpg_level    category
# car_name       object
# model          object
# dtype: object

# %%
print(len(mtcars[mtcars['mpg'] > 25]))
# Out:
# 6

# %%
mtcars[mtcars['mpg'] > 25]
# Out:
#                  mpg cyl   disp   hp  drat     wt   qsec        vs      am  \
# Fiat 128        32.4   4   78.7   66  4.08  2.200  19.47  Straight  manual
# Honda Civic     30.4   4   75.7   52  4.93  1.615  18.52  Straight  manual
# Toyota Corolla  33.9   4   71.1   65  4.22  1.835  19.90  Straight  manual
# Fiat X1-9       27.3   4   79.0   66  4.08  1.935  18.90  Straight  manual
# Porsche 914-2   26.0   4  120.3   91  4.43  2.140  16.70   Vshaped  manual
# Lotus Europa    30.4   4   95.1  113  3.77  1.513  16.90  Straight  manual
#
#                gear carb mpg_level        car_name           model
# Fiat 128          4    1      High        Fiat 128        Fiat 128
# Honda Civic       4    2      High     Honda Civic     Honda Civic
# Toyota Corolla    4    1      High  Toyota Corolla  Toyota Corolla
# Fiat X1-9         4    1    Medium       Fiat X1-9       Fiat X1-9
# Porsche 914-2     5    2    Medium   Porsche 914-2   Porsche 914-2
# Lotus Europa      5    2      High    Lotus Europa    Lotus Europa

# %%
mtcars[mtcars['wt'] >= 5]
# Out:
#                       mpg cyl   disp   hp  drat     wt   qsec       vs    am  \
# Cadillac Fleetwood   10.4   8  472.0  205  2.93  5.250  17.98  Vshaped  auto
# Lincoln Continental  10.4   8  460.0  215  3.00  5.424  17.82  Vshaped  auto
# Chrysler Imperial    14.7   8  440.0  230  3.23  5.345  17.42  Vshaped  auto
#
#                     gear carb mpg_level             car_name  \
# Cadillac Fleetwood     3    4       Low   Cadillac Fleetwood
# Lincoln Continental    3    4       Low  Lincoln Continental
# Chrysler Imperial      3    4       Low    Chrysler Imperial
#
#                                    model
# Cadillac Fleetwood    Cadillac Fleetwood
# Lincoln Continental  Lincoln Continental
# Chrysler Imperial      Chrysler Imperial

# %%
mtcars[mtcars['mpg_level'] == 'High' ]
# Out:
#                  mpg cyl  disp   hp  drat     wt   qsec        vs      am  \
# Fiat 128        32.4   4  78.7   66  4.08  2.200  19.47  Straight  manual
# Honda Civic     30.4   4  75.7   52  4.93  1.615  18.52  Straight  manual
# Toyota Corolla  33.9   4  71.1   65  4.22  1.835  19.90  Straight  manual
# Lotus Europa    30.4   4  95.1  113  3.77  1.513  16.90  Straight  manual
#
#                gear carb mpg_level        car_name           model
# Fiat 128          4    1      High        Fiat 128        Fiat 128
# Honda Civic       4    2      High     Honda Civic     Honda Civic
# Toyota Corolla    4    1      High  Toyota Corolla  Toyota Corolla
# Lotus Europa      5    2      High    Lotus Europa    Lotus Europa

# %%
mtcars.query("mpg < 23")
# Out:
#                       mpg cyl   disp   hp  drat     wt   qsec        vs  \
# Mazda RX4            21.0   6  160.0  110  3.90  2.620  16.46   Vshaped
# Mazda RX4 Wag        21.0   6  160.0  110  3.90  2.875  17.02   Vshaped
# Datsun 710           22.8   4  108.0   93  3.85  2.320  18.61  Straight
# Hornet 4 Drive       21.4   6  258.0  110  3.08  3.215  19.44  Straight
# Hornet Sportabout    18.7   8  360.0  175  3.15  3.440  17.02   Vshaped
# Valiant              18.1   6  225.0  105  2.76  3.460  20.22  Straight
# Duster 360           14.3   8  360.0  245  3.21  3.570  15.84   Vshaped
# Merc 230             22.8   4  140.8   95  3.92  3.150  22.90  Straight
# Merc 280             19.2   6  167.6  123  3.92  3.440  18.30  Straight
# Merc 280C            17.8   6  167.6  123  3.92  3.440  18.90  Straight
# Merc 450SE           16.4   8  275.8  180  3.07  4.070  17.40   Vshaped
# Merc 450SL           17.3   8  275.8  180  3.07  3.730  17.60   Vshaped
# Merc 450SLC          15.2   8  275.8  180  3.07  3.780  18.00   Vshaped
# Cadillac Fleetwood   10.4   8  472.0  205  2.93  5.250  17.98   Vshaped
# Lincoln Continental  10.4   8  460.0  215  3.00  5.424  17.82   Vshaped
# Chrysler Imperial    14.7   8  440.0  230  3.23  5.345  17.42   Vshaped
# Toyota Corona        21.5   4  120.1   97  3.70  2.465  20.01  Straight
# Dodge Challenger     15.5   8  318.0  150  2.76  3.520  16.87   Vshaped
# AMC Javelin          15.2   8  304.0  150  3.15  3.435  17.30   Vshaped
# Camaro Z28           13.3   8  350.0  245  3.73  3.840  15.41   Vshaped
# Pontiac Firebird     19.2   8  400.0  175  3.08  3.845  17.05   Vshaped
# Ford Pantera L       15.8   8  351.0  264  4.22  3.170  14.50   Vshaped
# Ferrari Dino         19.7   6  145.0  175  3.62  2.770  15.50   Vshaped
# Maserati Bora        15.0   8  301.0  335  3.54  3.570  14.60   Vshaped
# Volvo 142E           21.4   4  121.0  109  4.11  2.780  18.60  Straight
#
#                          am gear carb mpg_level             car_name  \
# Mazda RX4            manual    4    4    Medium            Mazda RX4
# Mazda RX4 Wag        manual    4    4    Medium        Mazda RX4 Wag
# Datsun 710           manual    4    1    Medium           Datsun 710
# Hornet 4 Drive         auto    3    1    Medium       Hornet 4 Drive
# Hornet Sportabout      auto    3    2    Medium    Hornet Sportabout
# Valiant                auto    3    1    Medium              Valiant
# Duster 360             auto    3    4       Low           Duster 360
# Merc 230               auto    4    2    Medium             Merc 230
# Merc 280               auto    4    4    Medium             Merc 280
# Merc 280C              auto    4    4    Medium            Merc 280C
# Merc 450SE             auto    3    3       Low           Merc 450SE
# Merc 450SL             auto    3    3    Medium           Merc 450SL
# Merc 450SLC            auto    3    3       Low          Merc 450SLC
# Cadillac Fleetwood     auto    3    4       Low   Cadillac Fleetwood
# Lincoln Continental    auto    3    4       Low  Lincoln Continental
# Chrysler Imperial      auto    3    4       Low    Chrysler Imperial
# Toyota Corona          auto    3    1    Medium        Toyota Corona
# Dodge Challenger       auto    3    2       Low     Dodge Challenger
# AMC Javelin            auto    3    2       Low          AMC Javelin
# Camaro Z28             auto    3    4       Low           Camaro Z28
# Pontiac Firebird       auto    3    2    Medium     Pontiac Firebird
# Ford Pantera L       manual    5    4       Low       Ford Pantera L
# Ferrari Dino         manual    5    6    Medium         Ferrari Dino
# Maserati Bora        manual    5    8       Low        Maserati Bora
# Volvo 142E           manual    4    2    Medium           Volvo 142E
#
#                                    model
# Mazda RX4                      Mazda RX4
# Mazda RX4 Wag              Mazda RX4 Wag
# Datsun 710                    Datsun 710
# Hornet 4 Drive            Hornet 4 Drive
# Hornet Sportabout      Hornet Sportabout
# Valiant                          Valiant
# Duster 360                    Duster 360
# Merc 230                        Merc 230
# Merc 280                        Merc 280
# Merc 280C                      Merc 280C
# Merc 450SE                    Merc 450SE
# Merc 450SL                    Merc 450SL
# Merc 450SLC                  Merc 450SLC
# Cadillac Fleetwood    Cadillac Fleetwood
# Lincoln Continental  Lincoln Continental
# Chrysler Imperial      Chrysler Imperial
# Toyota Corona              Toyota Corona
# Dodge Challenger        Dodge Challenger
# AMC Javelin                  AMC Javelin
# Camaro Z28                    Camaro Z28
# Pontiac Firebird        Pontiac Firebird
# Ford Pantera L            Ford Pantera L
# Ferrari Dino                Ferrari Dino
# Maserati Bora              Maserati Bora
# Volvo 142E                    Volvo 142E

# %%
mtcars.filter(items = ['mpg','hp'])
# Out:
#                       mpg   hp
# Mazda RX4            21.0  110
# Mazda RX4 Wag        21.0  110
# Datsun 710           22.8   93
# Hornet 4 Drive       21.4  110
# Hornet Sportabout    18.7  175
# Valiant              18.1  105
# Duster 360           14.3  245
# Merc 240D            24.4   62
# Merc 230             22.8   95
# Merc 280             19.2  123
# Merc 280C            17.8  123
# Merc 450SE           16.4  180
# Merc 450SL           17.3  180
# Merc 450SLC          15.2  180
# Cadillac Fleetwood   10.4  205
# Lincoln Continental  10.4  215
# Chrysler Imperial    14.7  230
# Fiat 128             32.4   66
# Honda Civic          30.4   52
# Toyota Corolla       33.9   65
# Toyota Corona        21.5   97
# Dodge Challenger     15.5  150
# AMC Javelin          15.2  150
# Camaro Z28           13.3  245
# Pontiac Firebird     19.2  175
# Fiat X1-9            27.3   66
# Porsche 914-2        26.0   91
# Lotus Europa         30.4  113
# Ford Pantera L       15.8  264
# Ferrari Dino         19.7  175
# Maserati Bora        15.0  335
# Volvo 142E           21.4  109
