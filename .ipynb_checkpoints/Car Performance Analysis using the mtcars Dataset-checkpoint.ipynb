# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns',None)

# %%
#Displaying first 5 rows of data
from pydataset import data
mtcars = data('mtcars')
mtcars.head(5)
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#                    carb
# Mazda RX4             4
# Mazda RX4 Wag         4
# Datsun 710            1
# Hornet 4 Drive        1
# Hornet Sportabout     2

# %%
#shape of dataset
mtcars.shape
# Out:
# (32, 11)

# %%
mtcars.columns
# Out:
# Index(['mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear',
#        'carb'],
#       dtype='object')

# %%
#Car list names
mtcars.index
# Out:
# Index(['Mazda RX4', 'Mazda RX4 Wag', 'Datsun 710', 'Hornet 4 Drive',
#        'Hornet Sportabout', 'Valiant', 'Duster 360', 'Merc 240D', 'Merc 230',
#        'Merc 280', 'Merc 280C', 'Merc 450SE', 'Merc 450SL', 'Merc 450SLC',
#        'Cadillac Fleetwood', 'Lincoln Continental', 'Chrysler Imperial',
#        'Fiat 128', 'Honda Civic', 'Toyota Corolla', 'Toyota Corona',
#        'Dodge Challenger', 'AMC Javelin', 'Camaro Z28', 'Pontiac Firebird',
#        'Fiat X1-9', 'Porsche 914-2', 'Lotus Europa', 'Ford Pantera L',
#        'Ferrari Dino', 'Maserati Bora', 'Volvo 142E'],
#       dtype='object')

# %%
#Data types
mtcars.dtypes
# Out:
# mpg     float64
# cyl       int64
# disp    float64
# hp        int64
# drat    float64
# wt      float64
# qsec    float64
# vs        int64
# am        int64
# gear      int64
# carb      int64
# dtype: object

# %%
#Summary Statistics
mtcars.describe
# Out:
# <bound method NDFrame.describe of                       mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4            21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag        21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710           22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive       21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout    18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# Valiant              18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# Duster 360           14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# Merc 240D            24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# Merc 230             22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# Merc 280             19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
# Merc 280C            17.8    6  167.6  123  3.92  3.440  18.90   1   0     4
# ...

# %%
#Missing Values check
mtcars.isnull
# Out:
# <bound method DataFrame.isnull of                       mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4            21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag        21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710           22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive       21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout    18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# Valiant              18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# Duster 360           14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# Merc 240D            24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# Merc 230             22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# Merc 280             19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
# Merc 280C            17.8    6  167.6  123  3.92  3.440  18.90   1   0     4
# ...

# %%
#car performance, fuel efficiency, and engine features
performance = mtcars[['hp', 'qsec', 'wt']]
fuel_efficiency = mtcars[['mpg']]
engine_features = mtcars[['cyl', 'disp', 'drat', 'carb']]

# %%
#visualization data in table
performance.head()
fuel_efficiency.head()
engine_features.head()
# Out:
#                    cyl   disp  drat  carb
# Mazda RX4            6  160.0  3.90     4
# Mazda RX4 Wag        6  160.0  3.90     4
# Datsun 710           4  108.0  3.85     1
# Hornet 4 Drive       6  258.0  3.08     1
# Hornet Sportabout    8  360.0  3.15     2

# %%
# using \n for naming the title 
print("Performance: \n", performance.head())
print("\nFuel Efficiency:\n", fuel_efficiency.head())
print("\nEngine Features:\n", engine_features.head())
# Out:
# Performance:
#                      hp   qsec     wt
# Mazda RX4          110  16.46  2.620
# Mazda RX4 Wag      110  17.02  2.875
# Datsun 710          93  18.61  2.320
# Hornet 4 Drive     110  19.44  3.215
# Hornet Sportabout  175  17.02  3.440
#
# Fuel Efficiency:
#                      mpg
# Mazda RX4          21.0
# Mazda RX4 Wag      21.0
# Datsun 710         22.8
# Hornet 4 Drive     21.4
# Hornet Sportabout  18.7
#
# Engine Features:
#                     cyl   disp  drat  carb
# Mazda RX4            6  160.0  3.90     4
# Mazda RX4 Wag        6  160.0  3.90     4
# Datsun 710           4  108.0  3.85     1
# Hornet 4 Drive       6  258.0  3.08     1
# Hornet Sportabout    8  360.0  3.15     2

# %%
# Scatter chart for Fuel Efficiency vs Horsepower
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(data=mtcars, x='hp', y='mpg')
plt.title("Fuel Efficiency vs Horsepower")
plt.show()

# %%
# Scatter chart for Engine displacement vs MPG
sns.scatterplot(data=mtcars, x='disp', y='mpg')
plt.title("Engine Displacement vs MPG")
plt.show()

# %%
summary = pd.concat([
    performance.mean().rename("Performance Avg"),
    fuel_efficiency.mean().rename("Fuel Avg"),
    engine_features.mean().rename("Engine Avg")
], axis=1)

print(summary)
# Out:
#       Performance Avg   Fuel Avg  Engine Avg
# hp          146.68750        NaN         NaN
# qsec         17.84875        NaN         NaN
# wt            3.21725        NaN         NaN
# mpg               NaN  20.090625         NaN
# cyl               NaN        NaN    6.187500
# disp              NaN        NaN  230.721875
# drat              NaN        NaN    3.596563
# carb              NaN        NaN    2.812500
